# %% [markdown]
# ## Load some data

# %%
import pandas as pd

df = pd.read_csv("data/people.csv")
df.head()
# Out:
#              name height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1           C-3PO    167   75        NaN         gold    yellow     112BBY
# 2           R2-D2     96   32        NaN  white, blue       red      33BBY
# 3     Darth Vader    202  136       none        white    yellow    41.9BBY
# 4     Leia Organa    150   49      brown        light     brown      19BBY
#
#    gender                         homeworld  \
# 0    male  https://swapi.dev/api/planets/1/
# 1     NaN  https://swapi.dev/api/planets/1/
# 2     NaN  https://swapi.dev/api/planets/8/
# 3    male  https://swapi.dev/api/planets/1/
# 4  female  https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0  ['https://swapi.dev/api/films/1/', 'https://sw...
# 1  ['https://swapi.dev/api/films/1/', 'https://sw...
# 2  ['https://swapi.dev/api/films/1/', 'https://sw...
# ...

# %% [markdown]
# ## Use production cleaning function

# %%
from processing import clean_people

clean_people(df).head()
# Out:
#              name  height   mass hair_color   skin_color eye_color  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue
# 1           C-3PO   167.0   75.0        NaN         gold    yellow
# 2           R2-D2    96.0   32.0        NaN  white, blue       red
# 3     Darth Vader   202.0  136.0       None        white    yellow
# 4     Leia Organa   150.0   49.0      brown        light     brown
#
#    birth_year  gender                               species  \
# 0   19.000000    male                                    []
# 1  112.000000     NaN  ['https://swapi.dev/api/species/2/']
# 2   33.000000     NaN  ['https://swapi.dev/api/species/2/']
# 3   41.900002    male                                    []
# 4   19.000000  female                                    []
#
#                        created                       edited  person_no
# 0  2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z          1
# ...

# %% [markdown]
# ## Why is the source code managed version of the function better?
# Because it is [type checked and tested](https://github.com/edvardlindelof/notebooks-vs-src/actions/runs/18378787946)
